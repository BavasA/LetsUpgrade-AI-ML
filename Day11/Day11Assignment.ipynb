# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
dataset1=pd.read_csv("general_data.csv")
dataset1.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
dataset1["Attrition"] = dataset1["Attrition"].map({"Yes":1,"No":0})
dataset1.head()
# Out:
#    Age  Attrition     BusinessTravel              Department  \
# 0   51          0      Travel_Rarely                   Sales
# 1   31          1  Travel_Frequently  Research & Development
# 2   32          0  Travel_Frequently  Research & Development
# 3   38          0         Non-Travel  Research & Development
# 4   32          0      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                 6          2  Life Sciences              1           1
# 1                10          1  Life Sciences              1           2
# 2                17          4          Other              1           3
# 3                 2          5  Life Sciences              1           4
# 4                10          1        Medical              1           5
#
#    Gender  ...  NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0  Female  ...                 1.0      Y                11              8
# ...

# %%
from scipy.stats import pearsonr
statst,p = pearsonr(dataset1.Age,dataset1.Attrition)
print(statst)
print(p)
print("{:f}".format(p))
# Out:
# -0.15920500686577965
# 1.996801615886744e-26
# 0.000000

# %% [markdown]
# # Correlation1:
# r value is not near to 1 or -1 so Age is not factor for attrition

# %%
statst,p = pearsonr(dataset1.DistanceFromHome,dataset1.Attrition)
print(statst)
print(p)
print("{:f}".format(p))
# Out:
# -0.009730141010179674
# 0.5182860428050771
# 0.518286

# %% [markdown]
# # Correlation2:
# r value is not near to 1 or -1 so DistanceFromHome is not a major factor for attritiom

# %%
statst,p = pearsonr(dataset1.MonthlyIncome,dataset1.Attrition)
print(statst)
print(p)
print("{:f}".format(p))
# Out:
# -0.031176281698115007
# 0.03842748490600132
# 0.038427

# %% [markdown]
# # Correlation3:
# r value is not near to 1 or -1 so MonthlyIncome is not a major factor for attritiom. Also 0.03 is less than 0.05 so null hypothesis is accpeted

# %%
ds2 = dataset1
#ds2["NumCompaniesWorked"] = ds2["NumCompaniesWorked"].map({"NA":0})
statst,p = pearsonr(ds2.PercentSalaryHike,ds2.Attrition)
print(statst)
print(p)
print("{:f}".format(p))
# Out:
# 0.03253259489105349
# 0.030743386433355353
# 0.030743

# %% [markdown]
# # Correlation4:
# r value is not near to 1 or -1 so PercentSalaryHike is not a major factor for attritiom. Also 0.03 is less than 0.05 so null hypothesis is accpeted

# %%
ds2 = dataset1
#ds2["NumCompaniesWorked"] = ds2["NumCompaniesWorked"].map({"NA":0})
statst,p = pearsonr(ds2.YearsAtCompany,ds2.Attrition)
print(statst)
print(p)
print("{:f}".format(p))
# Out:
# -0.1343922139899772
# 3.1638831224877484e-19
# 0.000000

# %% [markdown]
# # Correlation5:
# r value is not near to 1 or -1 so YearsAtCompany is not a major factor for attritiom. Also 0.03 is less than 0.05 so null hypothesis is accpeted
